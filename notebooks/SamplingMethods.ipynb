# %% [markdown]
# <a href="https://colab.research.google.com/github/xmpuspus/Lectures/blob/master/notebooks/SamplingMethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('bank.csv')
data.head()
# Out:
#    age         job  marital  education  ... pdays  previous poutcome deposit
# 0   59      admin.  married  secondary  ...    -1         0  unknown     yes
# 1   56      admin.  married  secondary  ...    -1         0  unknown     yes
# 2   41  technician  married  secondary  ...    -1         0  unknown     yes
# 3   55    services  married  secondary  ...    -1         0  unknown     yes
# 4   54      admin.  married   tertiary  ...    -1         0  unknown     yes
#
# [5 rows x 17 columns]

# %% [markdown]
# # Random Sampling

# %%
data.sample(10) # sample randomly from dataset
# Out:
#        age          job   marital  education  ... pdays  previous poutcome deposit
# 327     39     services   married  secondary  ...    -1         0  unknown     yes
# 1792    35      student    single  secondary  ...    78         8  success     yes
# 7721    31   management   married  secondary  ...    -1         0  unknown      no
# 9472    34     services    single  secondary  ...    -1         0  unknown      no
# 9375    55  blue-collar   married  secondary  ...    -1         0  unknown      no
# 806     36   management    single   tertiary  ...    -1         0  unknown     yes
# 5079    42  blue-collar   married  secondary  ...   106         1  failure     yes
# 7172    26  blue-collar   married    primary  ...    -1         0  unknown      no
# 10625   31   management    single   tertiary  ...    -1         0  unknown      no
# 8770    53     services  divorced    primary  ...    -1         0  unknown      no
#
# [10 rows x 17 columns]

# %% [markdown]
# # Systematic Sampling

# %%
nth_interval = 5 # nth interval to be sample
data[::nth_interval]
# Out:
#        age            job   marital  ... previous poutcome  deposit
# 0       59         admin.   married  ...        0  unknown      yes
# 5       42     management    single  ...        0  unknown      yes
# 10      38         admin.    single  ...        0  unknown      yes
# 15      35     management  divorced  ...        0  unknown      yes
# 20      28         admin.  divorced  ...        0  unknown      yes
# 25      35    blue-collar    single  ...        0  unknown      yes
# 30      32    blue-collar   married  ...        0  unknown      yes
# 35      32     management    single  ...        0  unknown      yes
# 40      60    blue-collar   married  ...        0  unknown      yes
# 45      35    blue-collar  divorced  ...        0  unknown      yes
# 50      41    blue-collar    single  ...        0  unknown      yes
# 55      40         admin.   married  ...        0  unknown      yes
# 60      51    blue-collar   married  ...        0  unknown      yes
# ...

# %% [markdown]
# # Stratified Sampling

# %% [markdown]
# ### 5 samples per job

# %%
N_SAMPLES = 5 # n samples per gender

data.groupby('job').apply(lambda x: x.sample(n=N_SAMPLES)) # Get N_SAMPLES from each category
# Out:
#                      age            job   marital  ... previous poutcome  deposit
# job                                                ...
# admin.        4323    38         admin.    single  ...        0  unknown      yes
#               7341    35         admin.   married  ...        0  unknown       no
#               1141    25         admin.    single  ...        0  unknown      yes
#               5661    39         admin.    single  ...        0  unknown       no
#               1881    36         admin.  divorced  ...        0  unknown      yes
# blue-collar   4647    49    blue-collar   married  ...        0  unknown      yes
#               7713    55    blue-collar   married  ...        0  unknown       no
#               10427   49    blue-collar   married  ...        0  unknown       no
#               5358    41    blue-collar   married  ...        0  unknown       no
#               5803    32    blue-collar   married  ...        0  unknown       no
# ...

# %% [markdown]
# ### 10 samples per education

# %%
N_SAMPLES = 1 # n samples per category

data.groupby('education').apply(lambda x: x.sample(n=N_SAMPLES)) # Get N_SAMPLES from each category
# Out:
#                 age          job  marital  ... previous poutcome  deposit
# education                                  ...
# primary   5610   55    housemaid  married  ...        0  unknown       no
# secondary 281    56  blue-collar  married  ...        0  unknown      yes
# tertiary  1796   39   management  married  ...        0  unknown      yes
# unknown   6725   38  blue-collar  married  ...        1  failure       no
#
# [4 rows x 17 columns]

# %% [markdown]
# # How many sample sizes do you need?
# [Math behind the algorithm](https://www.qualtrics.com/experience-management/research/determine-sample-size/)
#
# [Reference](http://veekaybee.github.io/)

# %%
import math
 
# SUPPORTED CONFIDENCE LEVELS: 50%, 68%, 90%, 95%, and 99%
confidence_level_constant = [50,.67], [68,.99], [90,1.64], [95,1.96], [99,2.57]
 
# CALCULATE THE SAMPLE SIZE
def sample_size(population_size, confidence_level, confidence_interval):
  """
  Inputs population size, confidence level and confidence interval
  """ 
  Z = 0.0
  p = 0.5
  e = confidence_interval/100.0
  N = population_size
  n_0 = 0.0
  n = 0.0
 
  # LOOP THROUGH SUPPORTED CONFIDENCE LEVELS AND FIND THE NUM STD
  # DEVIATIONS FOR THAT CONFIDENCE LEVEL
  for i in confidence_level_constant:
    if i[0] == confidence_level:
      Z = i[1]
 
  if Z == 0.0:
    return -1
 
  # CALC SAMPLE SIZE
  n_0 = ((Z**2) * p * (1-p)) / (e**2)
 
  # ADJUST SAMPLE SIZE FOR FINITE POPULATION
  n = n_0 / (1 + ((n_0 - 1) / float(N)) )
 
  return int(math.ceil(n)) # THE SAMPLE SIZE

# %% [markdown]
# To run this code, just change the population size, confidence level and confidence interval.

# %%
population_size = 7000000000
confidence_level = 99.0
confidence_interval = 2.0

samples = sample_size(population_size, confidence_level, confidence_interval)

print (f"SAMPLE SIZE: {samples}")
# Out:
# SAMPLE SIZE: 4129
