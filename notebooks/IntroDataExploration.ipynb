# %% [markdown]
# <a href="https://colab.research.google.com/github/xmpuspus/Lectures/blob/master/notebooks/IntroDataExploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Explore your Data

# %% [markdown]
# ### Import Packages

# %%
# IMPORT GENERIC PACKAGES
import numpy as np # numerical calc package
import pandas as pd # holds data
import matplotlib.pyplot as plt # plotting library
import seaborn as sns # pretty plotting

sns.set(rc={'figure.figsize':(20,10)})

# %% [markdown]
# ### Load Data

# %%
# # Diabetes Dataset
# url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

# names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
# data = pd.read_csv(url, names=names)

# Advertising Dataset

# url = 'http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv'


data = pd.read_csv("Advertising.csv", index_col=0) # Load Data

# %% [markdown]
# ### Peek at your Data

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Dimensions and Data Types

# %% [markdown]
# How many campaigns have we had?

# %%
# Dimensions
data.shape
# Out:
# (200, 4)

# %%
# Data Types
data.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# - What are the average TV, radio, and newspaper ad expenditures?
# - How much sales do we have on average?
# - At one point, what is the maximum TV ad expense we've ever done?
# - Do we deviate greatly/slightly from our ad expenses?

# %%
data.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Which direction is the ad expenditures skewed towards?

# %%
data.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %% [markdown]
# ### Correlations
#
# - How correlated are ad expenditures with sales?

# %%
sns.heatmap(data.corr(), annot = True)

# %%
sns.pairplot(data[data.columns[:4]])

# %% [markdown]
# # Save Images to Desktop

# %%
from google.colab import files
sns.pairplot(data[data.columns[:4]]);

# Save figure to colab
plt.savefig('pairplots.png')

# Save to Desktop
files.download('pairplots.png')

# %% [markdown]
# # END OF CODE
